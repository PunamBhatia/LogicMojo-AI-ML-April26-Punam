# %% [markdown]
# <a href="https://colab.research.google.com/github/PunamBhatia/LogicMojo-AI-ML-April26-Punam/blob/main/BuildUserConfigurationManager.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Build a User Configuration Manager
# In this lab, you will build a User Configuration Manager that allows users to manage their settings such as theme, language, and notifications. You will implement functions to add, update, delete, and view user settings.

# %%
def add_setting(settings, tup):
    key=tup[0].lower()
    value=tup[1].lower()

    if(key in settings):
        return f"Setting '{key}' already exists! Cannot add a new setting with this name."
    else:
        settings[key]=value
        return f"Setting '{key}' added with value '{value}' successfully!"

def update_setting(settings, tup):
    key=tup[0].lower()
    value=tup[1].lower()

    if(key in settings):
        settings[key]=value
        return f"Setting '{key}' updated to '{value}' successfully!"
    else:
        return f"Setting '{key}' does not exist! Cannot update a non-existing setting."


def delete_setting(settings, key):
    key=key.lower()

    print(key)
    if(key in settings):
        del settings[key]
        return f"Setting '{key}' deleted successfully!"
    else:
        return "Setting not found!"

def view_settings(settings):
    if(not settings):
        return "No settings available."
    else:
        kv=''
        for k,v in settings.items():
            kv+=k.title()+ ": "+v+"\n"
        return "Current User Settings:\n"+kv


test_settings={
    'theme':'nature',
    'language':'English',
    'notification':'off'
}
