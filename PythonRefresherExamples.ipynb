# %% [markdown]
# <a href="https://colab.research.google.com/github/PunamBhatia/LogicMojo-AI-ML-April26-Punam/blob/main/PythonRefresherExamples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
my_list=[10,20,30,40,50,60,70]
print(my_list[2:5])
print(my_list[::-1])

my_list1=[1,2,3,4,5,6,7,8]
print(my_list1[1:6:3])
# Out:
# [30, 40, 50]
# [70, 60, 50, 40, 30, 20, 10]
# [2, 5]

# %%
num = int(input("Enter a number : "))
cube=num**3
if(cube > 50):
  print("Cube of ",num," Massive Number :",cube)
else:
  print("Small Number")
print("Execution completed")
# Out:
# Enter a number : 6
# Cube of  6  Massive Number : 216
# Execution completed

# %%
new_password= input("Enter a new password: ")
confirm_password= input("Reenter the password to verify: ")
if(new_password==confirm_password):
  print("Verified Successfully")
else:
  print("Verification Failed")
# Out:
# Enter a new password: abcd
# Reenter the password to verify: Abcd
# Verification Failed

# %%
while True:
  number=int(input("Enter a number : "))
  if(number==5):
    break;
  elif(number %4==0):
    continue;
  print(number**2)
# Out:
# Enter a number : 3
# 9
# Enter a number : 4
# Enter a number : 7
# 49
# Enter a number : 5
